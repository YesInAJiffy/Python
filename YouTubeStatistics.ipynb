# %% [markdown]
# <a href="https://colab.research.google.com/github/YesInAJiffy/Python/blob/main/YouTubeStatistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


'''
categories = ["Have Channels", "1000 Subs", "10K Subs", "100K", "1Mil", "10 Mil", "50 Mil"]
total_value = 2600  # 2.6 Bn Adjust this value to represent the total sum of all percentages
percentages = [x / total_value * 100 for x in [113.9, 10.1, 2, .3211, 32300/1000000, 1100/1000000, 35/1000000]]  # Calculate percentages
'''

print("\033[31mYoutube has 2.6 billion active users. And there are 113.9 million YouTube channels. \033[0m")  # Red color code
dark_blue_color = "\033[34m"
text_to_print = "Which means out of the 2.6 billion active YouTube users, just 4.4% have their own channel."
end_code = "\033[0m"
print(dark_blue_color + text_to_print + end_code)
print("\033[92m_______________________________________________________________________________________________________________________\033[0m")  # Bright green code
print(" ")
categories = ["All", ">1000 and <10K", ">10K and <100K", ">100K and <1Mil", ">1 Mil and <10Mil", ">10 Mil and <50Mil", ">50 Mil and <100Mil", ">100 Mil"]
userinText = ["113.9 Million", "10.1 Million", "2 Million", "321.1K", "32.3K", "1.1K", "35", "10"]
total_value = 113.9  # 2.6 Bn Adjust this value to represent the total sum of all percentages
users = [ 113900000, 10100000, 2000000, 321100, 32300, 1100, 35, 5]
percentages = [x / total_value * 100 for x in [ 113.9, 10.1, 2, .3211, 32300/1000000, 1100/1000000, 35/1000000, 5/1000000]]  # Calculate percentages
i =0
for number in percentages:
  formatted_number = "{:.6f}".format(number)  # Prints 0.0000001234
  user_count = "{:.0f}".format(users[i])  # Prints 0.0000001234
  out_of_x_str = f"1 out of {100 / number:.1f}"
  chan_own = user_count + " (" + userinText[i] +")"
  print(f"Channel Owners {chan_own:26} : Subscribers {categories[i]:20} : Percentage {formatted_number:12} : {out_of_x_str}")
  i = i + 1



# Calculate bubble sizes based on percentages (adjust scaling factor as needed)
bubble_sizes = [p * 1000 for p in percentages]  # Scale percentage to desired bubble size

# Create a bubble chart
plt.figure(figsize=(8, 6))
plt.scatter(categories, [1 for _ in categories], s=bubble_sizes, c='blue', alpha=0.7, edgecolors='black')  # Set y to 1 for category labels

# Add category labels and title
plt.xlabel("Categories")
plt.ylabel("Percentage")
plt.title("Bubble represents the percentage of users in each category")

# Add percentages as text labels to bubbles (optional)
#for i, (txt, size) in enumerate(zip(categories, percentages)):
#    plt.text(i, 1 + size/200, f"{txt} - {size:.1f}%", ha='center')  # Adjust vertical position for readability

plt.xticks(rotation=45)  # Rotate category labels for better readability (optional)
plt.yticks([])  # Hide unnecessary y-axis ticks

plt.grid(True, linestyle='--', alpha=0.6, which='both', axis='x')  # Adjust grid style (optional)
plt.tight_layout()
plt.show()



numbers = percentages


# Scaling factor for bubble size (adjust as needed)
scaling_factor = 50000

# Create a scatter plot with bubble sizes based on numbers
plt.figure(figsize=(12, 10))
#plt.scatter(range(len(numbers)), numbers, s=[n * scaling_factor for n in numbers], c='purple', alpha=0.7, edgecolors='black')
plt.scatter(categories, users, s=[n * scaling_factor for n in numbers], c='purple', alpha=0.7, edgecolors='black')

# Add labels and title
plt.xlabel("Index")  # Replace with your specific label if needed
plt.ylabel("Subscriber Count")
plt.title("Bubble Size Represents Number")

# Optional: Add data point labels (numbers) above the bubbles
#for i, num in enumerate(numbers):
#    plt.text(i, num + 5, str(num), ha='center')  # Adjust vertical offset for readability

plt.grid(True)
plt.show()
# Out:
# Youtube has 2.6 billion active users. And there are 113.9 million YouTube channels.
# Which means out of the 2.6 billion active YouTube users, just 4.4% have their own channel.
# _______________________________________________________________________________________________________________________
#
# Channel Owners 113900000 (113.9 Million)  : Subscribers All                  : Percentage 100.000000   : 1 out of 1.0
# Channel Owners 10100000 (10.1 Million)    : Subscribers >1000 and <10K       : Percentage 8.867428     : 1 out of 11.3
# Channel Owners 2000000 (2 Million)        : Subscribers >10K and <100K       : Percentage 1.755926     : 1 out of 56.9
# Channel Owners 321100 (321.1K)            : Subscribers >100K and <1Mil      : Percentage 0.281914     : 1 out of 354.7
# Channel Owners 32300 (32.3K)              : Subscribers >1 Mil and <10Mil    : Percentage 0.028358     : 1 out of 3526.3
# ...

# %% [markdown]
# 🧟"It is easy to lie with statistics, but it is easier to lie without them." - Frederick Mosteller
#
# 📅"If you torture the data long enough, it will confess to anything." - Ronald Coase
#
# ⏰"Without data, you're just another person with an opinion." - W. Edwards Deming
